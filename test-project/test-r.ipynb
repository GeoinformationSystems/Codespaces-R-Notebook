# %%
runif(10)
# Out:
#  [1] 0.749331189 0.182752667 0.502427644 0.223406261 0.007664373 0.228088705
#  [7] 0.344351395 0.552066793 0.894227488 0.817503603

# %%
plot(runif(10))
# Out:
# plot without title
